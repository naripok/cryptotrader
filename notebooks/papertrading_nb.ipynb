# %%
import sys
sys.path.insert(0, '../')
import logging
logging.basicConfig(level=logging.ERROR)

import pandas as pd
import numpy as np
from datetime import datetime, timedelta, timezone

from cryptotrader.envs.trading import PaperTradingEnvironment, PaperTradingDataFeed
from cryptotrader.envs.utils import convert_and_clean, convert_to
from cryptotrader.agents import apriori
from cryptotrader.exchange_api.poloniex import Poloniex

from time import time, sleep

from bokeh.io import output_notebook
output_notebook()
# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e1bec268-c1b7-49ca-990a-2d53955f8b83">Loading BokehJS ...</span>
#     </div>

# %%
obs_steps = 300
period = 5
pairs = ["USDT_BTC", "USDT_ETH", "USDT_LTC", "USDT_XRP"]
init_funds = {"BTC":'0.00000000', "ETH":'0.00000000', "LTC":'0.00000000', "XRP":'0.00000000', "USDT":'100.00000000'}

tapi = Poloniex()
tapi = PaperTradingDataFeed(tapi, period, pairs, init_funds)

env = PaperTradingEnvironment(period, obs_steps, tapi, 'dev_tapi_env')
env.add_pairs(pairs)
env.fiat = 'USDT'

# env.set_email('fernando.canteruccio@gmail.com', 'password')

obs = env.reset()
# Out:
# INFO:dev_tapi_env:[Trading Environment initialization]
# Trading Environment Initialized!
#
# INFO:dev_tapi_env:[<function TradingEnvironment.set_email at 0x7f972092c730>]
# Email report address set to: fernando.canteruccio@gmail.com

# %%
agent = apriori.MomentumTrader(env._fiat)
agent.set_params(**{'mean_type': 'kama', 'ma1': 15, 'ma2': 101, 'std_span': 197, 'std_weight_down': 2.8864218854262513, 'std_weight_up': 1.0309225567510296})
# agent = apriori.DummyTrader(fiat="USDT")
agent.trade(env, verbose=True)
# Out:
# Executing paper trading with 5 min frequency.
# Initial portfolio value: 100 fiat units.
# >> step 3, Uptime: 0 days 00:09:27.370308, Crypto prices: [Decimal('5730.15093678'), Decimal('292.00000000'), Decimal('54.11195447'), Decimal('0.19800686')], Portval: 100.00, Last action: {'LTC': 0.0, 'USDT': 1.0, 'BTC': 0.0, 'XRP': 0.0, 'ETH': 0.0, 'online': 1.0}
# Keyboard Interrupt: Stoping cryptotrader
# Elapsed steps: 3
# Uptime: 0 days 00:09:39.514673
# Final Portval: 100.0000000000000000

# %%
env.plot_results();
