# %%
import sys
sys.path.insert(0, '../')
import logging
logging.basicConfig(level=logging.ERROR)

from datetime import datetime, timedelta, timezone

from cryptotrader.envs.trading import PaperTradingEnvironment, PaperTradingDataFeed
from cryptotrader.agents import apriori
from cryptotrader.exchange_api.poloniex import Poloniex
from cryptotrader.envs.utils import make_balance

from bokeh.io import output_notebook
output_notebook()
# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ce4da7ed-cdf4-43fd-9924-572914a6694b">Loading BokehJS ...</span>
#     </div>

# %%
# Simulation Params
test_name = 'dev_tapi_env'
obs_steps = 3 # Observation steps
period = 5 # Observation period
pairs = ["USDT_BTC", "USDT_ETH", "USDT_LTC", "USDT_XRP", "USDT_XMR", "USDT_ETC", "USDT_ZEC", "USDT_DASH"] # Universe
fiat_symbol = 'USDT' # Quote symbol
init_funds = make_balance(crypto=0.01, fiat=100.0, pairs=pairs) # Initial portfolio
# Email data for reporting
# email = 'email@gmail.com'
# password = 'password'

# %%
# Env setup
tapi = Poloniex()
tapi = PaperTradingDataFeed(tapi, period, pairs, init_funds)

env = PaperTradingEnvironment(period, obs_steps, tapi, test_name)
env.add_pairs(pairs)
env.fiat = fiat_symbol

# Email for report generation (Gmail only)
# env.set_email(email, password)

obs = env.reset()
# Out:
# INFO:dev_tapi_env:[Trading Environment initialization]
# Trading Environment Initialized!

# %%
env.portfolio_df
# Out:
#                                          BTC         ETH         LTC  \
# 2017-11-17 12:50:25.170567+00:00  0.01000000  0.01000000  0.01000000
#
#                                          XRP         XMR         ETC  \
# 2017-11-17 12:50:25.170567+00:00  0.01000000  0.01000000  0.01000000
#
#                                          ZEC        DASH          USDT  \
# 2017-11-17 12:50:25.170567+00:00  0.01000000  0.01000000  100.00000000
#
#                                        portval
# 2017-11-17 12:50:25.170567+00:00  190.34519732

# %%
env.get_sampled_portfolio()
# Out:
#                                   BTC         ETH         LTC         XRP  \
# 2017-11-17 12:50:00+00:00  0.01000000  0.01000000  0.01000000  0.01000000
#
#                                   XMR         ETC         ZEC        DASH  \
# 2017-11-17 12:50:00+00:00  0.01000000  0.01000000  0.01000000  0.01000000
#
#                                    USDT       portval
# 2017-11-17 12:50:00+00:00  100.00000000  190.34519732

# %%
env.get_sampled_portfolio()
# Out:
#                                   BTC         ETH         LTC         XRP  \
# 2017-11-17 12:50:00+00:00  0.01000000  0.01000000  0.01000000  0.01000000
#
#                                   XMR         ETC         ZEC        DASH  \
# 2017-11-17 12:50:00+00:00  0.01000000  0.01000000  0.01000000  0.01000000
#
#                                    USDT       portval
# 2017-11-17 12:50:00+00:00  100.00000000  190.34519732

# %%
env.get_history(portfolio_vector=True)
# Out:
#                                 USDT_BTC                                \
#                                     open           high            low
# 2017-11-17 12:55:00+00:00  7795.00000000  7795.00000000  7695.00000000
# 2017-11-17 13:00:00+00:00  7722.16922037  7800.00000000  7722.16922037
# 2017-11-17 13:05:00+00:00  7785.00000000  7785.00000000  7785.00000000
#
#                                                                        \
#                                    close           volume         BTC
# 2017-11-17 12:55:00+00:00  7722.16922037  801355.06201017  0.01000000
# 2017-11-17 13:00:00+00:00  7785.00000000  367671.20144246  0.01000000
# 2017-11-17 13:05:00+00:00  7785.00000000             0E-8  0.01000000
#
#                                USDT_ETH                              \
#                                    open          high           low
# 2017-11-17 12:55:00+00:00  329.28071928  331.00000000  328.07540301
# 2017-11-17 13:00:00+00:00  329.68031967  331.09899727  329.34065934
# 2017-11-17 13:05:00+00:00  329.64000007  329.64000007  329.64000007
#
#                                              ...           USDT_ZEC  \
#                                   close      ...              close
# 2017-11-17 12:55:00+00:00  329.68031967      ...       287.70000113
# 2017-11-17 13:00:00+00:00  329.64000007      ...       287.00000019
# 2017-11-17 13:05:00+00:00  329.64000007      ...       287.00000019
#
#                                                          USDT_DASH  \
#                                   volume         ZEC          open
# 2017-11-17 12:55:00+00:00  6576.50367726  0.01000000  416.24500000
# 2017-11-17 13:00:00+00:00  4118.35735063  0.01000000  415.01284319
# 2017-11-17 13:05:00+00:00           0E-8  0.01000000  416.24500000
#
#                                                                      \
#                                    high           low         close
# 2017-11-17 12:55:00+00:00  417.44999967  415.01284319  415.01284319
# 2017-11-17 13:00:00+00:00  416.99999997  414.19150931  416.24500000
# 2017-11-17 13:05:00+00:00  416.24500000  416.24500000  416.24500000
#
#                                                               USDT
#                                   volume        DASH          USDT
# 2017-11-17 12:55:00+00:00  1233.98022042  0.01000000  100.00000000
# 2017-11-17 13:00:00+00:00  4562.71082796  0.01000000  100.00000000
# 2017-11-17 13:05:00+00:00           0E-8  0.01000000  100.00000000
#
# [3 rows x 49 columns]

# %%
# Run simulation
agent = apriori.TestAgent(env.get_observation(True).shape)
# agent = apriori.PAMRTrader(sensitivity=0.04, C=2500, variant='PAMR2')
agent.trade(env, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7223f276c93d> in <module>()
#       1 # Run simulation
# ----> 2 agent = apriori.TestAgent(env.get_observation(True).shape)
#       3 # agent = apriori.PAMRTrader(sensitivity=0.04, C=2500, variant='PAMR2')
#       4 agent.trade(env, verbose=True)
#
# /home/tau/PycharmProjects/cryptotrader/cryptotrader/envs/trading.py in get_observation(self, portfolio_vector)
#     711     def get_observation(self, portfolio_vector=False):
#     712         try:
# --> 713             self.obs_df = self.get_history(portfolio_vector=portfolio_vector)
#     714             return self.obs_df
#     715
#
# /home/tau/PycharmProjects/cryptotrader/cryptotrader/envs/trading.py in get_history(self, start, end, portfolio_vector)
#     667                 for symbol in self.pairs:
#     668                     keys.append(symbol)
# --> 669                     history = self.get_ohlc(symbol, index)
#     670
#     671                     history = pd.concat([history, port_vec[symbol.split('_')[1]]], axis=1)
#
# /home/tau/PycharmProjects/cryptotrader/cryptotrader/envs/trading.py in get_ohlc(self, symbol, index)
#     616                                                                         period=self.period * 60,
#     617                                                                         start=datetime.timestamp(start),
# --> 618                                                                         end=datetime.timestamp(end)),
#     619                                                                         nrows=index.shape[0])
#     620         # TODO 1 FIND A BETTER WAY
#
# /home/tau/PycharmProjects/cryptotrader/cryptotrader/envs/trading.py in returnChartData(self, currencyPair, period, start, end)
#      83         """
#      84         try:
# ---> 85             return self.tapi.returnChartData(currencyPair, period, start=start, end=end)
#      86
#      87         except PoloniexError:
#
# /home/tau/PycharmProjects/cryptotrader/cryptotrader/exchange_api/poloniex.py in returnChartData(self, currencyPair, period, start, end)
#     334             'period': str(period),
#     335             'start': str(start),
# --> 336             'end': str(end)
#     337         })
#     338
#
# /home/tau/PycharmProjects/cryptotrader/cryptotrader/exchange_api/poloniex.py in retrying(*args, **kwargs)
#     146                 try:
#     147                     # attempt call
# --> 148                     return func(*args, **kwargs)
#     149
#     150                 # we need to try again
#
# /home/tau/PycharmProjects/cryptotrader/cryptotrader/exchange_api/poloniex.py in __call__(self, command, args)
#     219
#     220             # send the call
# --> 221             ret = _get(**payload)
#     222
#     223             # return data
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# /home/tau/Envs/cryptotrader/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      58     family = allowed_gai_family()
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#      62         sock = None
#
# /usr/local/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     741     # and socket type values to enum constants.
#     742     addrlist = []
# --> 743     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     744         af, socktype, proto, canonname, sa = res
#     745         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
# Plot results
env.plot_results();
